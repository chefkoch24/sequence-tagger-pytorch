# %%
from torch.utils.data import DataLoader
from model import SimpleSequenceTagger
from ner_dataset import NERDataset
import numpy as np

# %%
dev_file = './data/dev.conll'  # path to training data
test_file = './data/test.conll'  # path to validation data
train_file = './data/train.conll'  # path to test data
num_epochs = 20
train_dataset = NERDataset(file=train_file)
train_dataloader = DataLoader(train_dataset, batch_size=1, shuffle=True)
dev_dataset = NERDataset(file=dev_file)
dev_dataloader = DataLoader(dev_dataset, batch_size=1, shuffle=True)
test_dataset = NERDataset(file=test_file)
test_dataloader = DataLoader(test_dataset, batch_size=1, shuffle=True)

# %%
seq_tagger = SimpleSequenceTagger(input_dim=50, hidden_dim=100, num_layers=1, class_size=9)
for epoch in range(num_epochs):
    loss = seq_tagger.train(data=train_dataloader, learning_rate=0.01)
    print("Iteration:", epoch, "Loss:", loss)
    metrics = seq_tagger.evaluate(dev_dataloader)
    print('DEV-Data','macro', metrics['f1_scores']['macro'], 'micro', metrics['f1_scores']['micro'])
# Out:
# Iteration: 0 Loss: 16.822690963745117
# DEV-Data macro 0.5287793277732318 micro 0.9188115727580701
# Iteration: 1 Loss: 10.39950942993164
# /Users/felix/PycharmProjects/ukp-test/model.py:87: RuntimeWarning: invalid value encountered in double_scalars
#   p = tp / sum_of_all_classified_elements_class  # calculate precison per class that already includes the tp
# DEV-Data macro nan micro 0.9170982438378568
# Iteration: 2 Loss: 0.8340609073638916
# DEV-Data macro 0.5753273390846158 micro 0.9188115727580701
# Iteration: 3 Loss: 0.3662041127681732
# DEV-Data macro 0.5787205257669387 micro 0.9210700517892604
# Iteration: 4 Loss: 2.5584282875061035
# DEV-Data macro 0.5790607375401877 micro 0.922432927066703
# Iteration: 5 Loss: 2.1972246170043945
# DEV-Data macro 0.582786017141365 micro 0.9216346715470581
# Iteration: 6 Loss: 0.8941321969032288
# DEV-Data macro 0.5704440044822259 micro 0.9236011058759395
# Iteration: 7 Loss: 8.772149085998535
# DEV-Data macro 0.5864310133677663 micro 0.9237373934036837
# Iteration: 8 Loss: 1.6950182914733887
# DEV-Data macro 0.6051110200919964 micro 0.9265604921926717
# Iteration: 9 Loss: 15.739957809448242
# DEV-Data macro 0.5938624801420157 micro 0.9258206456134885
# Iteration: 10 Loss: 1.9878031015396118
# DEV-Data macro 0.605007437231607 micro 0.9272029905377517
# Iteration: 11 Loss: 2.4825806617736816
# DEV-Data macro 0.6035347729455438 micro 0.9258206456134885
# Iteration: 12 Loss: 1.7363085746765137
# DEV-Data macro 0.5981953559876756 micro 0.9262100385499007
# Iteration: 13 Loss: 2.39963698387146
# DEV-Data macro 0.5708805227326182 micro 0.9214789143724933
# Iteration: 14 Loss: 1.194506287574768
# DEV-Data macro 0.6104727424445552 micro 0.9273976870059577
# Iteration: 15 Loss: 2.5584282875061035
# DEV-Data macro 0.6025842528932422 micro 0.9271056423036486
# Iteration: 16 Loss: 2.0993239879608154
# DEV-Data macro 0.60306914026827 micro 0.9264631439585685
# Iteration: 17 Loss: 2.5584282875061035
# DEV-Data macro 0.6038882105028145 micro 0.9263657957244655
# Iteration: 18 Loss: 10.276290893554688
# DEV-Data macro 0.6085474159120431 micro 0.9278649585296522
# Iteration: 19 Loss: 2.865002393722534
# DEV-Data macro 0.6113167941491849 micro 0.9283906389938087

# %%
metrics = seq_tagger.evaluate(test_dataloader)
print('TEST-Data','macro', metrics['f1_scores']['macro'], 'micro', metrics['f1_scores']['micro'])
wrong_word_predictions = metrics['word_statistics']['fail']
wrong_word_predictions = [v for v in wrong_word_predictions if v[1] >= 8]
print('TEST-Data', 'wrong_predicted_words', wrong_word_predictions)
context_statistics = metrics['context_statistics']
print('TEST-Data', 'context_statistics', context_statistics)
# Out:
# TEST-Data macro 0.5933550105318696 micro 0.9140734359857866
# TEST-Data wrong_predicted_words [('world', 68), ('new', 55), ('of', 36), ('national', 36), ('madrid', 31), ('real', 25), ('party', 25), ('open', 24), ('united', 24), ('south', 20), ('fe', 20), ('wto', 19), ('santa', 19), ('league', 18), ('newsroom', 16), ('norilsk', 16), ('state', 15), ('city', 15), ('bre-x', 15), ('chicago', 15), ('west', 14), ('york', 14), ('louis', 14), ('university', 14), ('korea', 14), ('east', 13), ('and', 13), ('ny', 13), ('jersey', 12), ('major', 12), ('lara', 12), ('american', 12), ('zealand', 12), ('super', 11), ('gmt', 11), ('melbourne', 11), ('i', 11), ('internet', 10), ('costa', 10), ('san', 10), ('institute', 10), ('western', 10), ('van', 10), ('kroons', 10), ('series', 9), ('colorado', 9), ('fifa', 9), ('ministry', 9), ('international', 9), ('washington', 9), ('est', 9), ('vancouver', 9), ('buffalo', 9), ('barbarians', 9), ('nymex', 9), ('mills', 9), ('council', 8), ('belo', 8), ('sakakibara', 8), ('bay', 8), ('gladishiva', 8), ('clarke', 8), ('british', 8), ('young', 8), ('zywiec', 8), ('munich', 8), ('wimbledon', 8), ('pace', 8), ('union', 8), ('central', 8), ('african', 8)]
# TEST-Data context_statistics [(',', 28), ('at', 19), ('said', 16), ('1996-12-06', 15), ("'s", 14), ("'s world cup", 12), ('-', 12), ('(', 10), ('was', 9), ('the world cup', 8), (', colorado 1996-12-07', 7), ('cup', 7), ('15', 7), ('the united nations', 7), ('jersey', 7), ('madrid', 7), ('1996-12-07', 7), ('has', 6), ('t pf pa', 6), ('bay', 6), ('cup super g', 6), ('division', 6), ('a world cup', 6), ('louis', 6), ('', 6), ('7', 6), ('8', 6), ('world series limited', 5), ('heidi zurbriggen (', 5), ('-- new york', 5), ('new york commodities', 5), ('york commodities desk', 5), ('stefanie schuster (', 5), ('pf pa ', 5), ('ice', 5), ('( est )', 5), ('14', 5), ('0', 5), ('barbara merlin (', 5), ('9', 5), ('isolde kostner (', 5), ('boxmeer', 5), ('22', 5), ('6', 5), ('the world series', 4), ('united arab emirates', 4), ('/', 4), ('( chicago newsdesk', 4), ('rio de janeiro', 4), ('york', 4), ('16', 4), ('2', 4), ('rangers', 4), ('miriam vogt (', 4), ('american', 4), ('svetlana gladishiva (', 4), ('12', 4), ("champions ' league", 4), ('martina ertl (', 4), ('south korea )', 4), ('group d ', 4), ('world grand prix', 4), ('conference', 4), ('( rangers )', 4), ('13', 4), ('of national hockey', 4), ('national hockey ', 4), ('97', 4), ('arab emirates 1996-12-06', 3), ('sun jun (', 3), ('in south lebanon', 3), ('chicago newsdesk 312-408-8720', 3), ('mines and energy', 3), ('and energy ministry', 3), ('fe', 3), ('office of fair', 3), ('st', 3), ('world war two', 3), ('basketball', 3), ('10', 3), ('-- london newsroom', 3), ('the party ,', 3), ('state', 3), ('games', 3), ('angeles', 3), ('willem ii tilburg', 3), ('regine cavagnoud (', 3), ('the melbourne cricket', 3), ('is', 3), ('van boxmeer said', 3), ('20', 3), ('the university of', 3), ('university of yangon', 3), ("south africa 's", 3), ('moines', 3), ('des moines 1996-12-06', 3), ('at chicago ', 3), ('central african republic', 3), ('maccabi tel aviv', 3), ('4', 3), ('ye zhaoying (', 3), ('real madrid ', 3), ('kim do hoon', 3), ('the internet ,', 3), ('5', 3), ('hwang sun hong', 3), ('camilla martin (', 3), ('new zealand )', 3), ('( wimbledon )', 3), ('the xinhua news', 2), ('van vuuren 65', 2), ('four-day sheffield shield', 2), ('at bellerive oval', 2), ('sybille brauner (', 2), ('elf refinery workers', 2), ('national bucharest are', 2), ('northern ireland .', 2), ("the ministry 's", 2), ('both bre-x and', 2), ('marianne brechu (', 2), ('the civil aviation', 2), ('the franco-african summit', 2), ('franco-african summit in', 2), ('jun', 2), ('allan budi kusuma', 2), ('- sheffield shield', 2), ('sheffield shield score', 2), ('new delhi 1996-12-06', 2), ('the european union', 2), ('of', 2), ('county', 2), ('chris witty (', 2), ('( us )', 2), ('/ red sea', 2), ('sheffield shield match', 2), ('tampa bay 8', 2), ('w okla fed', 2), ('the national weather', 2), ('national weather service', 2), ('the gates of', 2), (': burke (', 2), ('-- u.s. municipal', 2), ('u.s. municipal desk', 2), ('nobel peace prize', 2), ('sheffield wednesday 1', 2), ('santa fe is', 2), ('romania', 2), (', xinhua said', 2), ('the rubber board', 2), ('the office of', 2), ('the security council', 2), ('security council has', 2), ('the commission said', 2), ('joao manuel pinto', 2), ('de janeiro 1996-12-06', 2), ('new zealand first', 2), ('paris st germain', 2), ('st germain 1', 2), ('c healy b', 2), ('war two .', 2), ('5 .750 -', 2), ('and cup ', 2), ('the lombardi award', 2), ('green bay packers', 2), ('teams', 2), ('sm pd lst', 2), ('northern ireland premier', 2), ('kinder bologna (', 2), ("in florida 's", 2), ('estudiantes madrid (', 2), ('the house of', 2), ('house of commons', 2), ('maccabi petah tikva', 2), ("cup winners '", 2), ("winners ' cup", 2), ('madlen brigger-summermatter (', 2), ('london newsroom +44', 2), ('newsroom +44 171', 2), ('antonio', 2), ('san antonio 3', 2), ("munich re 's", 2), ('bayer leverkusen 2', 2), ('i', 2), ('sidi kreir /', 2), ('the wto was', 2), ('hapoel tel aviv', 2), (')', 2), ('regina ha ...

# %%
metrics['confusion_matrix']
# Out:
# array([[1.4210e+03, 1.3000e+01, 1.2000e+02, 2.1000e+01, 1.3000e+01,
#         1.0000e+00, 1.0000e+01, 2.9000e+01, 4.0000e+01],
#        [3.0000e+01, 4.1100e+02, 2.8000e+01, 1.4000e+01, 1.1000e+01,
#         2.0000e+00, 8.0000e+00, 1.0000e+01, 1.8800e+02],
#        [2.7100e+02, 4.0000e+01, 9.4000e+02, 3.8000e+01, 1.8000e+01,
#         1.0000e+00, 7.5000e+01, 4.5000e+01, 2.3300e+02],
#        [2.3000e+01, 3.0000e+00, 4.6000e+01, 1.0370e+03, 4.0000e+00,
#         0.0000e+00, 9.0000e+00, 3.6600e+02, 1.2900e+02],
#        [8.5000e+01, 1.7000e+01, 6.0000e+00, 1.3000e+01, 7.6000e+01,
#         2.0000e+00, 9.0000e+00, 5.0000e+00, 4.4000e+01],
#        [2.0000e+00, 8.0000e+00, 7.0000e+00, 2.0000e+00, 7.0000e+00,
#         8.3000e+01, 2.0000e+00, 2.0000e+00, 1.0300e+02],
#        [1.4600e+02, 8.0000e+00, 1.2500e+02, 2.1000e+01, 4.3000e+01,
#         0.0000e+00, 1.5800e+02, 2.7000e+01, 3.0700e+02],
#        [2.0000e+01, 3.0000e+00, 4.6000e+01, 3.4700e+02, 4.0000e+00,
#         9.0000e+00, 6.0000e+00, 5.4500e+02, 1.7600e+02],
#        [1.4100e+02, 3.0000e+01, 9.6000e+01, 4.6000e+01, 2.6000e+01,
#         1.0000e+01, 1.3600e+02, 6.4000e+01, 3.7774e+04]])

# %%
# world = ambiguity
# 1996-12-06 date

# %%
# 2022 https://arxiv.org/pdf/2204.04391.pdf
# https://arxiv.org/pdf/1910.02403.pdf

# https://kiarashk76.github.io/docs/DL4NLP.pdf
